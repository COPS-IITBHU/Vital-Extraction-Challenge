# %%
import os
import pandas as pd
import numpy as np
import cv2 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PlotDigitizerModule
from PlotDigitizerModule.plotdigitizer import run

# %%
img_path = r"./graph_img3.jpg"
plot_img_name = "plot.png"

# %%
import cv2 as cv
def remove_grid(
    orig, num_iter=3, background_color: int = 255, grid_size: int = 2
) -> np.ndarray:
    img = orig.copy()
    thres = cv.threshold(img, 0, 255, cv.THRESH_BINARY_INV + cv.THRESH_OTSU)[1]
    # Remove horizontal lines
    horizontal_kernel = cv.getStructuringElement(cv.MORPH_RECT, (40, 1))
    remove_horizontal = cv.morphologyEx(
        thres, cv.MORPH_OPEN, horizontal_kernel, iterations=num_iter
    )
    cnts = cv.findContours(remove_horizontal, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    for c in cnts:
        cv.drawContours(img, [c], -1, background_color, grid_size)

    # Remove vertical lines
    vertical_kernel = cv.getStructuringElement(cv.MORPH_RECT, (1, 40))
    remove_vertical = cv.morphologyEx(
        thres, cv.MORPH_OPEN, vertical_kernel, iterations=num_iter
    )
    cnts = cv.findContours(remove_vertical, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    for c in cnts:
        cv.drawContours(img, [c], -1, background_color, grid_size)
    return img

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44008/3882072693.py in <module>
#       1 import cv2
#       2 img = cv2.imread(img_path)
# ----> 3 cnts = cv2.findContours(img, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-so3wle8q\opencv\modules\imgproc\src\contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
points = run(img_path=img_path, plot=plot_img_name)
print(len(points))
# Out:
# 900

# %%
x = [float(p[0]) for p in points]
y = [float(p[1]) for p in points]

plt.rcParams["figure.figsize"] = [10.00, 3]
plt.rcParams["figure.autolayout"] = True

plt.subplot(211)
plt.plot(x, y)
plt.show()

plt.subplot(212)
plt.imshow(mpimg.imread(img_path), aspect='auto')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PlotDigitizerModule
from PlotDigitizerModule.plotdigitizer import run

def digitize_graph(image_path, plot_img_name='plot.png'):
    points = run(img_path=image_path, plot=plot_img_name)
    x = [float(p[0]) for p in points]
    y = [float(p[1]) for p in points]
    plt.rcParams["figure.figsize"] = [10.00, 3]
    plt.rcParams["figure.autolayout"] = True

    plt.subplot(211)
    plt.plot(x, y)
    plt.show()

    plt.subplot(212)
    plt.imshow(mpimg.imread(image_path), aspect='auto')
    plt.show()

# %%
digitize_graph('graph_img7.jpg')

# %%
plt.rcParams["figure.figsize"] = [10.00, 1]
plt.rcParams["figure.autolayout"] = True

plt.plot(x,y2)

# %%
import random

y2 = [0]*900
for i in range(900):
    y2[i] = y[300:600][i%300] + random.random()*0.1-0.05

# %%
import random
random.random()
# Out:
# 0.8943387995998179

# %%
cropped = cv2.imread('graph_img4.jpg')
normalizedImg = np.zeros((cropped.shape[0], cropped.shape[1]))
cropped = cv2.normalize(cropped,  normalizedImg, 0, 255, cv2.NORM_MINMAX)
hsv = cv2.cvtColor(cropped, cv2.COLOR_RGB2HSV)
mask = cv2.inRange(hsv, (40, 90, 40), (80, 255, 255))
imask = mask>0
green = np.zeros_like(cropped, np.uint8)
green[imask] = cropped[imask]

plt.imshow(green)

# %%
0.4*255
# Out:
# 102.0
